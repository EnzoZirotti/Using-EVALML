# %%
#import dependencies 
import evalml
from evalml import AutoMLSearch
from evalml.utils import infer_feature_types
import woodwork as ww

# %%
#I would like to add that all of the data for this have been
# already changed into the datatype float or int for the machine learning purpose.
# Will need to do this for a fresh dataset.
#pulling in demo data.
X, y = evalml.demos.diabetes.load_diabetes()
# Out:
#          Number of Features
# Numeric                  10
#
# Number of training examples: 442
# Targets
# 200    1.36%
# 72     1.36%
# 90     1.13%
# 178    1.13%
# 71     1.13%
#        ...
# 73     0.23%
# 222    0.23%
# 86     0.23%
# 79     0.23%
# 57     0.23%
# Name: target, Length: 214, dtype: object

# %%
# To validate the result of the pipeline creation save some of the data as a holdout set
X_train, X_holdout, y_train, y_holdout = evalml.preprocessing.split_data(
    X,y, problem_type="regression", test_size=0.2
)

# %%
#I adjusted problem type to regression since we are using regression.
# I also adjusted the objectives as F1 is for classification and for regression it is R2,MAE or MSE
automl = AutoMLSearch(
    X_train=X_train,
    y_train=y_train,
    problem_type="regression",
    objective="R2",
    max_batches=5,
    verbose=True,
)
# Out:
# AutoMLSearch will use mean CV score to rank pipelines.

# %%
#Searching for the best pipelines
automl.search()
# Out:
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for R2.
# Greater score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 5 batches for a total of None pipelines.
# Allowed model families:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type': 'scatter',
#               'uid': '650c9da2-6972-4f00-8893-080471b9b3be',
#               'x': [],
#               'y': []},
#              {'marker': {'color': 'gray'},
#               'mode': 'markers',
#               'name': 'Iter score',
#               'type': 'scatter',
#               'uid': '17057b66-a189-434a-adf0-adc6f8308f34',
#               'x': [],
#               'y': []}],
#     'layout': {'showlegend': False,
#                'template': '...',
#                'title': {'text': ('Pipeline Search: Iteration vs.' ... 'ore at current iteration</sub>')},
# ...

# %%
automl.rankings
# Out:
#       id                                      pipeline_name  search_order  \
# 0    107  LightGBM Regressor w/ Imputer + Select Columns...           107
# 1    153  Elastic Net Regressor w/ Imputer + Standard Sc...           153
# 56    64  Extra Trees Regressor w/ Imputer + Select Colu...            64
# 170    1  Random Forest Regressor w/ Imputer + RF Regres...             1
# 185    3  XGBoost Regressor w/ Imputer + Select Columns ...             3
# 196    0                  Mean Baseline Regression Pipeline             0
#
#      ranking_score  mean_cv_score  standard_deviation_cv_score  \
# 0         0.491609       0.491609                     0.017571
# 1         0.490883       0.490883                     0.033613
# 56        0.480836       0.480836                     0.031648
# 170       0.398746       0.398746                     0.026759
# 185       0.243731       0.243731                     0.043180
# 196      -0.006613      -0.006613                     0.005752
#
# ...

# %%
#See more detail
automl.describe_pipeline(1)
# Out:
# ***********************************************************************
# * Random Forest Regressor w/ Imputer + RF Regressor Select From Model *
# ***********************************************************************
#
# Problem Type: regression
# Model Family: Random Forest
#
# Pipeline Steps
# ...
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * boolean_impute_strategy : most_frequent
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 	 * boolean_fill_value : None
# 2. RF Regressor Select From Model
# 	 * number_features : None
# 	 * n_estimators : 10
# 	 * max_depth : None
# 	 * percent_features : 0.5
# 	 * threshold : median
# 	 * n_jobs : -1
# 3. Random Forest Regressor
# 	 * n_estimators : 100
# 	 * max_depth : 6
# 	 * n_jobs : -1
#
# Training
# ...
# Training for regression problems.
# Total training time (including CV): 1.0 seconds
#
# Cross Validation
# ----------------
# ...

# %%
# Select the best pipeline and score it on our holdout data
pipeline = automl.best_pipeline
pipeline.score(X_holdout, y_holdout, ["R2"])
# Out:
# OrderedDict([('R2', 0.2624806540878919)])

# %%
# Create a sample X_new dataset (replace this with your actual data)
# Here, we create a new DataFrame with the same feature structure as X_train
X_new = pd.DataFrame({
    'feature1': [value1, value2, value3],  # Replace with your actual values
    'feature2': [value4, value5, value6],  # Replace with your actual values
    # Add other feature columns as needed
    })

# Make predictions on the new data
predictions = best_pipeline.predict(X_new)

# Print the predictions
print(predictions)
