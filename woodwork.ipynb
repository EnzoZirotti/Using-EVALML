# %%
import pandas as pd   
import woodwork as ww

df = pd.read_csv("https://oss.alteryx.com/datasets/online-retail-logs-2018-08-28.csv")
df["order_product_id"] = range(df.shape[0])

# %%
df
# Out:
#        order_id product_id                          description  quantity  \
# 0        536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1        536365      71053                  WHITE METAL LANTERN         6
# 2        536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3        536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4        536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...         ...        ...                                  ...       ...
# 401599   581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 401600   581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 401601   581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 401602   581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 401603   581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                  order_date  unit_price customer_name         country  \
# 0       2010-12-01 08:26:00      4.2075  Andrea Brown  United Kingdom
# 1       2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom
# 2       2010-12-01 08:26:00      4.5375  Andrea Brown  United Kingdom
# 3       2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom
# 4       2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom
# ...                     ...         ...           ...             ...
# 401599  2011-12-09 12:50:00      1.4025  Regina Green          France
# 401600  2011-12-09 12:50:00      3.4650  Regina Green          France
# 401601  2011-12-09 12:50:00      6.8475  Regina Green          France
# 401602  2011-12-09 12:50:00      6.8475  Regina Green          France
# 401603  2011-12-09 12:50:00      8.1675  Regina Green          France
#
#           total  cancelled  order_product_id
# 0       25.2450      False                 0
# 1       33.5610      False                 1
# 2       36.3000      False                 2
# 3       33.5610      False                 3
# 4       33.5610      False                 4
# ...         ...        ...               ...
# 401599  16.8300      False            401599
# 401600  20.7900      False            401600
# 401601  27.3900      False            401601
# 401602  27.3900      False            401602
# 401603  24.5025      False            401603
#
# [401604 rows x 11 columns]

# %%
#initializing woodwork on a dataframe an optional name parameter can be specified to label the data.
df.ww.init(name="retail")
df.ww

# Woodwork uses a weak reference for maintaining a reference from the accessor to the dataframe.
#Instead of calling it pd.read_ect.ww.init() always pull in the data into a var and then init()
# Out:
#                    Physical Type Logical Type Semantic Tag(s)
# Column
# order_id                category  Categorical    ['category']
# product_id              category  Categorical    ['category']
# description             category  Categorical    ['category']
# quantity                   int64      Integer     ['numeric']
# order_date        datetime64[ns]     Datetime              []
# unit_price               float64       Double     ['numeric']
# customer_name           category  Categorical    ['category']
# country                 category  Categorical    ['category']
# total                    float64       Double     ['numeric']
# cancelled                   bool      Boolean              []
# order_product_id           int64      Integer     ['numeric']

# %%
# Creates a new dataframe containing first 5 rows
head_df = df.ww.head(5)
head_df.ww
# Once woodwork is initialized on a dataframe it is recommended to go through the ww namespace
# when performing dataframe operations to avoid invalidating woodwork's typing info.
# Out:
#                    Physical Type Logical Type Semantic Tag(s)
# Column
# order_id                category  Categorical    ['category']
# product_id              category  Categorical    ['category']
# description             category  Categorical    ['category']
# quantity                   int64      Integer     ['numeric']
# order_date        datetime64[ns]     Datetime              []
# unit_price               float64       Double     ['numeric']
# customer_name           category  Categorical    ['category']
# country                 category  Categorical    ['category']
# total                    float64       Double     ['numeric']
# cancelled                   bool      Boolean              []
# order_product_id           int64      Integer     ['numeric']

# %%
head_df
# Out:
#   order_id product_id                          description  quantity  \
# 0   536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365      71053                  WHITE METAL LANTERN         6
# 2   536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            order_date  unit_price customer_name         country   total  \
# 0 2010-12-01 08:26:00      4.2075  Andrea Brown  United Kingdom  25.245
# 1 2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom  33.561
# 2 2010-12-01 08:26:00      4.5375  Andrea Brown  United Kingdom  36.300
# 3 2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom  33.561
# 4 2010-12-01 08:26:00      5.5935  Andrea Brown  United Kingdom  33.561
#
#    cancelled  order_product_id
# 0      False                 0
# 1      False                 1
# 2      False                 2
# 3      False                 3
# 4      False                 4

# %%
#Changing Logical type to a more appropriate value
#ww.types to check column types to infer from
df.ww.set_types(
    logical_types={
        "customer_name": "PersonFullName",
        "country": "Categorical",
        "order_product_id": "Categorical"
    }
)
df.ww.types.head()
# Out:
#               Physical Type Logical Type Semantic Tag(s)
# Column
# order_id           category  Categorical    ['category']
# product_id         category  Categorical    ['category']
# description        category  Categorical    ['category']
# quantity              int64      Integer     ['numeric']
# order_date   datetime64[ns]     Datetime              []

# %%
#Selecting Columns based on logical types
numeric_df = df.ww.select(["Integer","Double"])
numeric_df.ww
# Out:
#            Physical Type Logical Type Semantic Tag(s)
# Column
# quantity           int64      Integer     ['numeric']
# unit_price       float64       Double     ['numeric']
# total            float64       Double     ['numeric']

# %%
numeric_df
# Out:
#         quantity  unit_price    total
# 0              6      4.2075  25.2450
# 1              6      5.5935  33.5610
# 2              8      4.5375  36.3000
# 3              6      5.5935  33.5610
# 4              6      5.5935  33.5610
# ...          ...         ...      ...
# 401599        12      1.4025  16.8300
# 401600         6      3.4650  20.7900
# 401601         4      6.8475  27.3900
# 401602         4      6.8475  27.3900
# 401603         3      8.1675  24.5025
#
# [401604 rows x 3 columns]

# %%
#Adding Semantic Tags
df.ww.set_types(semantic_tags={"description": "product_details","total": "currency"})
df.ww
# Out:
#                    Physical Type    Logical Type  \
# Column
# order_id                category     Categorical
# product_id              category     Categorical
# description             category     Categorical
# quantity                   int64         Integer
# order_date        datetime64[ns]        Datetime
# unit_price               float64          Double
# customer_name             string  PersonFullName
# country                 category     Categorical
# total                    float64          Double
# cancelled                   bool         Boolean
# order_product_id        category     Categorical
#
#                                   Semantic Tag(s)
# Column
# order_id                             ['category']
# product_id                           ['category']
# description       ['product_details', 'category']
# quantity                              ['numeric']
# order_date                                     []
# unit_price                            ['numeric']
# customer_name                                  []
# country                              ['category']
# total                     ['currency', 'numeric']
# cancelled                                      []
# order_product_id                     ['category']

# %%
#Select columns based on semantic tags
category_df = df.ww.select("category")
category_df.ww
# Out:
#                  Physical Type Logical Type                  Semantic Tag(s)
# Column
# order_id              category  Categorical                     ['category']
# product_id            category  Categorical                     ['category']
# description           category  Categorical  ['product_details', 'category']
# country               category  Categorical                     ['category']
# order_product_id      category  Categorical                     ['category']

# %%
#Select columns using multiple semantic tags
category_numeric_df = df.ww.select(["numeric","category"])
category_numeric_df.ww
# Out:
#                  Physical Type Logical Type                  Semantic Tag(s)
# Column
# order_id              category  Categorical                     ['category']
# product_id            category  Categorical                     ['category']
# description           category  Categorical  ['product_details', 'category']
# quantity                 int64      Integer                      ['numeric']
# unit_price             float64       Double                      ['numeric']
# country               category  Categorical                     ['category']
# total                  float64       Double          ['currency', 'numeric']
# order_product_id      category  Categorical                     ['category']

# %%
mixed_df = df.ww.select(["Boolean","product_details"])
mixed_df.ww
# Out:
#             Physical Type Logical Type                  Semantic Tag(s)
# Column
# description      category  Categorical  ['product_details', 'category']
# cancelled            bool      Boolean                               []

# %%
# To pull individual columns
multi_col = df.ww[["product_id","total","unit_price"]]
multi_col.ww
# Out:
#            Physical Type Logical Type          Semantic Tag(s)
# Column
# product_id      category  Categorical             ['category']
# total            float64       Double  ['currency', 'numeric']
# unit_price       float64       Double              ['numeric']

# %%
# removing semantic tag
df.ww.remove_semantic_tags({"description":"product_details"})
df.ww
# Out:
#                    Physical Type    Logical Type          Semantic Tag(s)
# Column
# order_id                category     Categorical             ['category']
# product_id              category     Categorical             ['category']
# description             category     Categorical             ['category']
# quantity                   int64         Integer              ['numeric']
# order_date        datetime64[ns]        Datetime                       []
# unit_price               float64          Double              ['numeric']
# customer_name             string  PersonFullName                       []
# country                 category     Categorical             ['category']
# total                    float64          Double  ['currency', 'numeric']
# cancelled                   bool         Boolean                       []
# order_product_id        category     Categorical             ['category']

# %%
# Designating certain columns as the woodwork index or time_index. set_index or set_time_index
df.ww.set_index("order_product_id")
df.ww.index
# Out:
# 'order_product_id'

# %%
df.ww.set_time_index("order_date")
df.ww.time_index
# Out:
# 'order_date'

# %%
df.ww
# Out:
#                    Physical Type    Logical Type          Semantic Tag(s)
# Column
# order_id                category     Categorical             ['category']
# product_id              category     Categorical             ['category']
# description             category     Categorical             ['category']
# quantity                   int64         Integer              ['numeric']
# order_date        datetime64[ns]        Datetime           ['time_index']
# unit_price               float64          Double              ['numeric']
# customer_name             string  PersonFullName                       []
# country                 category     Categorical             ['category']
# total                    float64          Double  ['currency', 'numeric']
# cancelled                   bool         Boolean                       []
# order_product_id        category     Categorical                ['index']

# %%
series = pd.Series([1,2,3], dtype="int64")
series.ww.init(logical_type="Integer")
series.ww
# Out:
# <Series: None (Physical Type = int64) (Logical Type = Integer) (Semantic Tags = {'numeric'})>

# %%
string_series = pd.Series(["a","b","c"], dtype="string")
ww_series = ww.init_series(string_series, logical_type="Categorical")
ww_series.ww
# Out:
# <Series: None (Physical Type = category) (Logical Type = Categorical) (Semantic Tags = {'category'})>

# %%
#Add a new semantic tag to the series
series.ww.add_semantic_tags("new_tag")
series.ww
# Out:
# <Series: None (Physical Type = int64) (Logical Type = Integer) (Semantic Tags = {'new_tag', 'numeric'})>

# %%
#Access Series properties 
series.ww.shape
# Out:
# (3,)

# %%
#Call a method sample
sample_series = series.ww.sample(2)
sample_series.ww
# Out:
# <Series: None (Physical Type = int64) (Logical Type = Integer) (Semantic Tags = {'new_tag', 'numeric'})>

# %%
#List Logical Types 
from woodwork.type_sys.utils import list_logical_types
list_logical_types()
# Out:
#                name       type_string  \
# 0           Address           address
# 1               Age               age
# 2     AgeFractional    age_fractional
# 3       AgeNullable      age_nullable
# 4           Boolean           boolean
# 5   BooleanNullable  boolean_nullable
# 6       Categorical       categorical
# 7       CountryCode      country_code
# 8      CurrencyCode     currency_code
# 9          Datetime          datetime
# 10           Double            double
# 11     EmailAddress     email_address
# 12         Filepath          filepath
# 13        IPAddress        ip_address
# 14          Integer           integer
# 15  IntegerNullable  integer_nullable
# 16          LatLong          lat_long
# 17  NaturalLanguage  natural_language
# 18          Ordinal           ordinal
# 19   PersonFullName  person_full_name
# 20      PhoneNumber      phone_number
# 21       PostalCode       postal_code
# 22    SubRegionCode   sub_region_code
# 23        Timedelta         timedelta
# 24              URL               url
# 25          Unknown           unknown
#
#                                           description    physical_type  \
# 0   Represents Logical Types that contain address ...           string
# 1   Represents Logical Types that contain whole nu...            int64
# 2   Represents Logical Types that contain non-nega...          float64
# 3   Represents Logical Types that contain whole nu...            Int64
# 4   Represents Logical Types that contain binary v...             bool
# 5   Represents Logical Types that contain binary v...          boolean
# 6   Represents Logical Types that contain unordere...         category
# 7   Represents Logical Types that use the ISO-3166...         category
# 8   Represents Logical Types that use the ISO-4217...         category
# 9   Represents Logical Types that contain date and...   datetime64[ns]
# 10  Represents Logical Types that contain positive...          float64
# 11  Represents Logical Types that contain email ad...           string
# 12  Represents Logical Types that specify location...           string
# 13  Represents Logical Types that contain IP addre...           string
# 14  Represents Logical Types that contain positive...            int64
# 15  Represents Logical Types that contain positive...            Int64
# 16  Represents Logical Types that contain latitude...           object
# 17  Represents Logical Types that contain text or ...           string
# 18  Represents Logical Types that contain ordered ...         category
# 19  Represents Logical Types that may contain firs...           string
# 20  Represents Logical Types that contain numeric ...           string
# 21  Represents Logical Types that contain a series...         category
# 22  Represents Logical Types that use the ISO-3166...         category
# 23  Represents Logical Types that contain values s...  timedelta64[ns]
# 24  Represents Logical Types that contain URLs, wh...           string
# 25  Represents Logical Types that cannot be inferr...           string
#
#    standard_tags  is_default_type  is_registered      parent_type
# 0             {}             True           True             None
# 1      {numeric}             True           True          Integer
# 2      {numeric}             True           True           Double
# 3      {numeric}             True           True  IntegerNullable
# 4             {}             True           True  BooleanNullable
# 5             {}             True           True             None
# 6     {category}             True           True             None
# 7     {category}             True           True      Categorical
# 8     {category}             True           True      Categorical
# 9             {}             True           True             None
# 10     {numeric}             True           True             None
# 11            {}             True           True          Unknown
# 12            {}             True           True             None
# 13            {}             True           True          Unknown
# 14     {numeric}             True           True  IntegerNullable
# 15     {numeric}             True           True             None
# 16            {}             True           True             None
# 17            {}             True           True             None
# 18    {category}             True           True      Categorical
# 19            {}             True           True             None
# 20            {}             True           True          Unknown
# 21    {category}             True           True      Categorical
# 22    {category}             True           True      Categorical
# 23            {}             True           True          Unknown
# 24            {}             True           True          Unknown
# 25            {}             True           True             None
